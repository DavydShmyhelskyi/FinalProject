# %%
# ================================
# RENDER IPYNB -> HTML REPORT
# ================================

# Встановлюємо робочу директорію
setwd("C:/Users/Graf David/R/FinalProject/src")

# Перевіряємо наявність файлу
if (!file.exists("Final_Report.ipynb")) {
  stop("❌ Файл Final_Report.ipynb не знайдено у папці src")
}

# Встановлення та підключення rmarkdown
if (!require("rmarkdown")) {
  install.packages("rmarkdown", dependencies = TRUE)
  library(rmarkdown)
}

# Генерація HTML
rmarkdown::render(
  input = "Final_Report.ipynb",
  output_format = "html_document"
)

cat("✅ HTML-файл Final_Report.html успішно створений\n")
